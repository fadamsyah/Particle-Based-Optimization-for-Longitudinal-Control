# %% [markdown]
# # IMPORT LIBRARY AND DATA

# %%
import numpy as np
import numba as nb
import math
import matplotlib.pyplot as plt
import pandas as pd
import time
from numba import njit, prange
from os import listdir
from os.path import isfile, join

# %matplotlib inline
plt.style.use(['science','ieee'])

# %%
df = pd.read_csv('../steady_state_response.csv')
v = np.array(df.ssv)
u = np.array(df.u)


plt.figure()
plt.scatter(v, u)
plt.xlabel('Steady state speed (m/s)')
plt.ylabel('Throttle')
plt.show()

# %% [markdown]
# # MAKE FUNCTION

# %% [markdown]
# ## Generate population

# %%
def generate_population(num, dim, rng):
    """
    Generate population:
        Input:
            num: number of population (integer)
            dim: number of parameters (integer)
            rng: range number used in initialization (list or numpy array)
        Output:
            pop: initial position of the population (numpy array)
    """
    pop = np.zeros((num,dim))
    for i in range(dim):
        lim = rng[i]
        pop[:, i] = np.random.uniform(lim[0], lim[1], size=num)
    return pop

# %% [markdown]
# ## Constraint

# %%
@njit
def admissible(param):
    b1, b2, b3 = param
    if b1 < 0. or b2 > 0. or b3 < 0.:
        return False
    else:
        return True
_ = admissible(np.random.randn(3))

# %% [markdown]
# ## Forward propagation

# %%
@njit
def forward_propagation(u, param):
    b1, b2, b3 = param
    
    out = b1 * (1 - np.exp(b2*(u))) + b3
    out = np.fmax(out, 0.)
    
    # When the vehicle is not moving
    out[u <= 1e-2] = 0.
    
    return out

_ = forward_propagation(np.array([0.0, 0.1]), np.ones(3)*0.5)

# %% [markdown]
# ## Cost and metric

# %%
@njit
def cost(u, v, param):
    error = v - forward_propagation(u, param)
    cost = np.mean(error**2)
    return cost
_ = cost(v, u, np.ones(3)*0.5)

# %%
@njit
def calculate_total_cost(param):    
    if admissible(param):
        loss = cost(v, u, param)
    else:
        loss = np.Inf
    return loss
_ = calculate_total_cost(np.ones(3)*0.5)

# %%
@njit(parallel=True)
def population_cost(population):
    length = population.shape[0]
    losses = np.zeros(length)
    for ii in prange(length):
        losses[ii] = calculate_total_cost(population[ii])
    return losses
_ = population_cost(np.random.randn(2,3))

# %% [markdown]
# ## Optimization Algorithm

# %%
@njit
def apso(population, loss_population, global_, global_loss, alpha0, beta):
    num = population.shape[0]
    dim = population.shape[1]
    
    # Initial conditions
    ppos_vector = np.copy(population)
    pbest_pos = np.copy(ppos_vector)
    pfit_value = np.copy(loss_population)
    gbest_pos = np.copy(global_)
    gfit_value = global_loss
    
    L = np.empty_like(population[0])
    for i in range(L.shape[0]):
        L[i] = np.max(population[:, i]) - np.min(population[:, i])
    
    for i in range(num):
        # Update the alpha value
        alpha = alpha0 * L
            
        # Update the velocity and position vector
        ppos_vector[i] = (1-beta)*ppos_vector[i] + alpha*np.random.normal(0,1) + beta*gbest_pos
        
        cost_func = calculate_total_cost(ppos_vector[i])
        
        # Update each values using the cost functions
        if(pfit_value[i] > cost_func):
            pfit_value[i] = cost_func
            pbest_pos[i] = np.copy(ppos_vector[i])
                
        if(gfit_value > cost_func):
            gfit_value = cost_func
            gbest_pos = np.copy(ppos_vector[i])
    
    return pbest_pos, pfit_value, gbest_pos, gfit_value
    
xx1 = np.ones((2, 3))*1.0
xx2 = np.ones(2)
xx3 = np.ones(3)*0.5
_ = apso(xx1, xx2, xx3, 100.0, 0.8, 1.5)

# %% [markdown]
# # SIMULATION

# %%
num = 25
n_sim = 50
n_itr = 5000

r_b1 = [0.,  2.]
r_b2 = [0., -2.]
r_b3 = [0.,  2.]

rng = [r_b1, r_b2, r_b3]
dim = len(rng)

alpha0 = 0.8
beta = 0.15

param_history = np.zeros((n_sim, dim))
loss_history = np.ones(n_sim)*np.Inf

the_best_param_history = np.zeros((n_itr, dim))
the_best_loss_history = np.zeros(n_itr)

for j in range(n_sim):
    population = generate_population(num, dim, rng)
    global_ = None
    global_loss_ = np.Inf
    
    loss_population = population_cost(population)
    loss_population[np.isnan(loss_population)] = np.Inf
    min_idx = np.argmin(loss_population)
    min_loss = loss_population[min_idx]
    if global_loss_ > min_loss:
        global_loss_ = min_loss
        global_ = np.copy(population[min_idx, :])
        
    global_history = np.empty((n_itr, dim))
    global_history[0] = global_
    global_loss_history = np.empty(n_itr)
    global_loss_history[0] = global_loss_
    for i in range(1, n_itr):
        # Particle Swarm Optimization
        population, loss_population, global_, global_loss_ = apso(population, loss_population, global_, global_loss_, alpha0, beta)
        
        global_history[i] = global_
        global_loss_history[i] = global_loss_
    
    if np.min(loss_history) > global_loss_history[-1]:
        the_best_loss_history = np.copy(global_loss_history)
        the_best_param_history = np.copy(global_history)
        
    param_history[j] = np.copy(global_history[-1])
    loss_history[j] = np.copy(global_loss_history[-1])
    
    print('simulation: {} || global loss: {:.10f} || the best loss: {:.10f}'.format(j, global_loss_history[-1], the_best_loss_history[-1]))
# Out:
# simulation: 0 || global loss: 0.0038724703 || the best loss: 0.0038724703
# simulation: 1 || global loss: 0.0089177227 || the best loss: 0.0038724703
# simulation: 2 || global loss: 0.0354285181 || the best loss: 0.0038724703
# simulation: 3 || global loss: 0.0013779541 || the best loss: 0.0013779541
# simulation: 4 || global loss: 0.0005812222 || the best loss: 0.0005812222
# simulation: 5 || global loss: 0.0000215454 || the best loss: 0.0000215454
# simulation: 6 || global loss: 0.0068467556 || the best loss: 0.0000215454
# simulation: 7 || global loss: 0.0001730653 || the best loss: 0.0000215454
# simulation: 8 || global loss: 0.0035066645 || the best loss: 0.0000215454
# simulation: 9 || global loss: 0.0274633887 || the best loss: 0.0000215454
# simulation: 10 || global loss: 0.0014642042 || the best loss: 0.0000215454
# simulation: 11 || global loss: 0.0040431975 || the best loss: 0.0000215454
# simulation: 12 || global loss: 0.0048955443 || the best loss: 0.0000215454
# simulation: 13 || global loss: 0.0111716689 || the best loss: 0.0000215454
# simulation: 14 || global loss: 0.0079450328 || the best loss: 0.0000215454
# simulation: 15 || global loss: 0.0053994793 || the best loss: 0.0000215454
# simulation: 16 || global loss: 0.0045007595 || the best loss: 0.0000215454
# simulation: 17 || global loss: 0.0041618241 || the best loss: 0.0000215454
# simulation: 18 || global loss: 0.0025354721 || the best loss: 0.0000215454
# simulation: 19 || global loss: 0.0117433927 || the best loss: 0.0000215454
# simulation: 20 || global loss: 0.0057876304 || the best loss: 0.0000215454
# simulation: 21 || global loss: 0.0107185278 || the best loss: 0.0000215454
# simulation: 22 || global loss: 0.0209172201 || the best loss: 0.0000215454
# simulation: 23 || global loss: 0.0038439430 || the best loss: 0.0000215454
# simulation: 24 || global loss: 0.0030002650 || the best loss: 0.0000215454
# simulation: 25 || global loss: 0.0017552286 || the best loss: 0.0000215454
# simulation: 26 || global loss: 0.0033749011 || the best loss: 0.0000215454
# simulation: 27 || global loss: 0.0027620396 || the best loss: 0.0000215454
# simulation: 28 || global loss: 0.0085517621 || the best loss: 0.0000215454
# simulation: 29 || global loss: 0.0016090099 || the best loss: 0.0000215454
# simulation: 30 || global loss: 0.0363779270 || the best loss: 0.0000215454
# simulation: 31 || global loss: 0.0023853879 || the best loss: 0.0000215454
# simulation: 32 || global loss: 0.0012908947 || the best loss: 0.0000215454
# simulation: 33 || global loss: 0.0380920046 || the best loss: 0.0000215454
# simulation: 34 || global loss: 0.0027745327 || the best loss: 0.0000215454
# simulation: 35 || global loss: 0.0000119963 || the best loss: 0.0000119963
# simulation: 36 || global loss: 0.0017062223 || the best loss: 0.0000119963
# simulation: 37 || global loss: 0.0120229456 || the best loss: 0.0000119963
# simulation: 38 || global loss: 0.0246626037 || the best loss: 0.0000119963
# simulation: 39 || global loss: 0.0037491786 || the best loss: 0.0000119963
# simulation: 40 || global loss: 0.0031859781 || the best loss: 0.0000119963
# simulation: 41 || global loss: 0.0040782808 || the best loss: 0.0000119963
# simulation: 42 || global loss: 0.0000117461 || the best loss: 0.0000117461
# simulation: 43 || global loss: 0.0001755112 || the best loss: 0.0000117461
# simulation: 44 || global loss: 0.0001170423 || the best loss: 0.0000117461
# simulation: 45 || global loss: 0.0056189911 || the best loss: 0.0000117461
# simulation: 46 || global loss: 0.0052782172 || the best loss: 0.0000117461
# simulation: 47 || global loss: 0.0092044880 || the best loss: 0.0000117461
# simulation: 48 || global loss: 0.0000117460 || the best loss: 0.0000117460
# simulation: 49 || global loss: 0.0001578941 || the best loss: 0.0000117460

# %%
# Save the simulation
np.save('result/param_history.npy', param_history)
np.save('result/loss_history.npy', loss_history)
np.save('result/the_best_loss_history.npy', the_best_loss_history)
np.save('result/the_best_param_history.npy', the_best_param_history)

f = open("result/sim.cfg", "w+")
f.writelines('num: {} # The number of flowers\n'.format(num))
f.writelines('n_sim: {} # The number of simulation loop\n'.format(n_sim))
f.writelines('n_itr: {} # The number of iteration for each simulation\n'.format(n_itr))
f.writelines('\n# The boundary of the initialization value\n')
f.writelines('r_b1: {}\n'.format(r_b1))
f.writelines('r_b2: {}\n'.format(r_b2))
f.writelines('r_b3: {}\n'.format(r_b3))
f.writelines('\n# The PSO hyperparameters\n')
f.writelines('alpha0: {}\n'.format(alpha0))
f.writelines('beta: {}\n'.format(beta))
f.close()

# %% [markdown]
# # RESULT

# %%
# # Load the model
the_best_param_history = np.load('result/the_best_param_history.npy')
the_best_loss_history = np.load('result/the_best_loss_history.npy')

# %%
print('Minimum Cost: {}'.format(the_best_loss_history[-1]))
print('Parameters:')
print(the_best_param_history[-1])
# Out:
# Minimum Cost: 1.1746041231389595e-05
# Parameters:
# [ 0.8500716  -0.14497909  0.09624485]

# %%
plt.scatter(v, u, linewidth=0.05)
plt.xlabel(r'Steady-State Speed $(m/s)$')
plt.ylabel('Throttle')
plt.title('Throttle vs Steady-State Speed')
plt.savefig('img/throttle_vs_speed', dpi=600, transparent=True, bbox_inches='tight',)
plt.show()

# %%
plt.scatter(v, u, label='Actual', linewidth=0.05)
plt.plot(v, forward_propagation(v, the_best_param_history[-1]), label='Prediction', color='red', linewidth=2)
plt.xlabel(r'Speed $(m/s)$')
plt.ylabel('Throttle')
plt.title('Prediction of Steady-State Response')
plt.legend()
plt.savefig('img/throttle_vs_speed_pred', dpi=600, transparent=True, bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
